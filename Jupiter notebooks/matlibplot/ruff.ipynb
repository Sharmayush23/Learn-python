# %%
from matplotlib import pyplot as plt
import numpy as np

growth_rate_x=[20.63,25.22,42.27,17.11,25.82,9.92,22.05,2]

lit_rate_y=[72.32,56.77,78.07,70.93,77.29,79.65,71.58,58.5]

# %%
plt.plot(growth_rate_x,lit_rate_y)

# %%
plt.title('graph')
plt.xlabel("growth_rate")
plt.ylabel("lit_rate")
plt.show()

# %%
x = np.arange(0, 5, 0.1)
y = np.sin(x)
plt.plot(x, y,)
plt.title("first graph")
plt.xlabel("sin")
plt.ylabel("x")
plt.show()
